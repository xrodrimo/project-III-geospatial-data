# %%
import requests
import json
import pandas as pd
import os
from dotenv import load_dotenv
load_dotenv()
token = os.getenv("token")

# %%
def requests_for_foursquare (query, lat, lon, cate, exclude, radius=500, limit=5):
    url = f"https://api.foursquare.com/v3/places/search?query={query}&ll={lat}%2C{lon}&radius={radius}&categories={cate}&exclude_chains={exclude}&sort=RELEVANCE&limit={limit}"

    headers = {
        "accept": "application/json",
        "Authorization": token
    }
    try:
        return requests.get(url, headers=headers).json()
    except:
        print("no :(")
        
def extracting_from_one_element (response):
    name = response["name"]
    distance = response["distance"]
    lat = response["geocodes"]["main"]["latitude"]
    lon = response["geocodes"]["main"]["longitude"]
    cat = response["categories"][0]["name"]
    print(cat)
    
    small_dict = {
    "name": name,
    "distance": distance,
    "lat": lat,
    "lon": lon,
    "category": cat
}
    return small_dict

# %%
# Starbucks nearby
lat = 37.77051
lon = -122.401581
query = "vegan"
cate = 13377
exclude = "as"
response = requests_for_foursquare(query, lat, lon,cate, exclude, radius=1000, limit=10)

def transform_request_into_df (response):
    list_of_dictionaries = [extracting_from_one_element (element) for element in response["results"]]
    return pd.DataFrame(list_of_dictionaries)
list_of_dictionaries = [extracting_from_one_element (element) for element in response["results"]]
df_pried = pd.DataFrame(list_of_dictionaries)
value_to_add = 'Starbucks'
df_pried['Type'] = value_to_add
df_pried
# Out:
# Website Designer
# Website Designer
# Website Designer
# Website Designer
# Website Designer
# Website Designer
# Website Designer
# Website Designer
# Website Designer
# Website Designer
#                          name  distance        lat         lon  \
# 0               Astro Studios       866  37.777792 -122.405048
# 1                     Manmade       382  37.773000 -122.404478
# 2                    Atomic D       386  37.774091 -122.400887
# 3           SF Website Design       479  37.774920 -122.402441
# 4                   Podomatic       843  37.776946 -122.406718
# 5               River Studios       919  37.777460 -122.407250
# 6              CyberProtocols       558  37.765579 -122.402823
# 7  Web Design Ecommerce & Web       567  37.774964 -122.398429
# 8            Ethos Technology       567  37.765427 -122.402240
# 9                     Webflow       627  37.766890 -122.407057
#
#            category       Type
# 0  Website Designer  Starbucks
# 1  Website Designer  Starbucks
# 2  Website Designer  Starbucks
# 3  Website Designer  Starbucks
# 4  Website Designer  Starbucks
# 5  Website Designer  Starbucks
# 6  Website Designer  Starbucks
# 7  Website Designer  Starbucks
# 8  Website Designer  Starbucks
# 9  Website Designer  Starbucks
